# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('wisc_bc_data.csv')

# %%
x=df.drop(['id','diagnosis'],axis=1)

# %% [markdown]
# ##### standardize the data

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
x_std= scaler.fit_transform(x)

# %%
x_std.shape
# Out:
# (569, 30)

# %% [markdown]
# ##### apply the pca

# %%
from sklearn.decomposition import PCA

# %%
# creat object
pca=PCA()

# %%
#apply alorithm
x_pca=pca.fit_transform(x_std)

# %%
x_pca
var= pca.explained_variance_ratio_
var
# Out:
# array([4.42720256e-01, 1.89711820e-01, 9.39316326e-02, 6.60213492e-02,
#        5.49576849e-02, 4.02452204e-02, 2.25073371e-02, 1.58872380e-02,
#        1.38964937e-02, 1.16897819e-02, 9.79718988e-03, 8.70537901e-03,
#        8.04524987e-03, 5.23365745e-03, 3.13783217e-03, 2.66209337e-03,
#        1.97996793e-03, 1.75395945e-03, 1.64925306e-03, 1.03864675e-03,
#        9.99096464e-04, 9.14646751e-04, 8.11361259e-04, 6.01833567e-04,
#        5.16042379e-04, 2.72587995e-04, 2.30015463e-04, 5.29779290e-05,
#        2.49601032e-05, 4.43482743e-06])

# %%
x_pca.shape
# Out:
# (569, 30)

# %%
plt.figure(figsize=(16,9))
plt.grid()
plt.xlabel('principal Components')
plt.ylabel('variance')
plt.xticks(range(1,31))
plt.bar(range(1,31),var)
# Out:
# <BarContainer object of 30 artists>

# %%
# creat object
pca=PCA(n_components=10)

# %%
x_pca=pca.fit_transform(x_std)

# %%
x_pca.shape
# Out:
# (569, 10)

# %%
x_pca
# Out:
# array([[ 9.19283683,  1.94858307, -1.12316617, ..., -0.3984092 ,
#         -0.15711493, -0.87740016],
#        [ 2.3878018 , -3.76817174, -0.52929268, ...,  0.24099073,
#         -0.71190809,  1.10699377],
#        [ 5.73389628, -1.0751738 , -0.5517476 , ...,  0.09737001,
#          0.02407229,  0.45428071],
#        ...,
#        [ 1.25617928, -1.90229671,  0.56273053, ...,  0.34188827,
#          0.39391458,  0.520874  ],
#        [10.37479406,  1.67201011, -1.87702933, ..., -0.28024169,
#         -0.54202904, -0.08929007],
#        [-5.4752433 , -0.67063679,  1.49044308, ...,  1.04634968,
#          0.37410934, -0.04771391]])

# %%
plt.figure(figsize=(16,9))
plt.grid()
plt.xlabel('principal Components')
plt.ylabel('variance')
plt.xticks(range(1,11))
plt.bar(range(1,11),pca.explained_variance_ratio_)
# Out:
# <BarContainer object of 10 artists>
