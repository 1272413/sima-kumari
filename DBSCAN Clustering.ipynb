# %%
import numpy as np
from sklearn.datasets import make_blobs
from sklearn.cluster import DBSCAN
import matplotlib.pyplot as plt

# %%
x,_= make_blobs(n_samples=300, centers=4, cluster_std=0.60, random_state=0)

# %%
_
# Out:
# array([1, 3, 0, 3, 1, 1, 2, 0, 3, 3, 2, 3, 0, 3, 1, 0, 0, 1, 2, 2, 1, 1,
#        0, 2, 2, 0, 1, 0, 2, 0, 3, 3, 0, 3, 3, 3, 3, 3, 2, 1, 0, 2, 0, 0,
#        2, 2, 3, 2, 3, 1, 2, 1, 3, 1, 1, 2, 3, 2, 3, 1, 3, 0, 3, 2, 2, 2,
#        3, 1, 3, 2, 0, 2, 3, 2, 2, 3, 2, 0, 1, 3, 1, 0, 1, 1, 3, 0, 1, 0,
#        3, 3, 0, 1, 3, 2, 2, 0, 1, 1, 0, 2, 3, 1, 3, 1, 0, 1, 1, 0, 3, 0,
#        2, 2, 1, 3, 1, 0, 3, 1, 1, 0, 2, 1, 2, 1, 1, 1, 1, 2, 1, 2, 3, 2,
#        2, 1, 3, 2, 2, 3, 0, 3, 3, 2, 0, 2, 0, 2, 3, 0, 3, 3, 3, 0, 3, 0,
#        1, 2, 3, 2, 1, 0, 3, 0, 0, 1, 0, 2, 2, 0, 1, 0, 0, 3, 1, 0, 2, 3,
#        1, 1, 0, 2, 1, 0, 2, 2, 0, 0, 0, 0, 1, 3, 0, 2, 0, 0, 2, 2, 2, 0,
#        2, 3, 0, 2, 1, 2, 0, 3, 2, 3, 0, 3, 0, 2, 0, 0, 3, 2, 2, 1, 1, 0,
#        3, 1, 1, 2, 1, 2, 0, 3, 3, 0, 0, 3, 0, 1, 2, 0, 1, 2, 3, 2, 1, 0,
#        1, 3, 3, 3, 3, 2, 2, 3, 0, 2, 1, 0, 2, 2, 2, 1, 1, 3, 0, 0, 2, 1,
#        3, 2, 0, 3, 0, 1, 1, 2, 2, 0, 1, 1, 1, 0, 3, 3, 1, 1, 0, 1, 1, 1,
#        3, 2, 3, 0, 1, 1, 3, 3, 3, 1, 1, 0, 3, 2])

# %%
x,y= make_blobs(n_samples=300, centers=10, cluster_std=0.60, random_state=0)

# %%
y
# Out:
# array([1, 2, 6, 5, 4, 1, 2, 9, 0, 7, 1, 9, 5, 2, 8, 8, 5, 8, 3, 9, 6, 8,
#        0, 8, 2, 5, 4, 7, 6, 7, 1, 6, 8, 9, 7, 0, 6, 1, 3, 3, 0, 1, 9, 1,
#        8, 7, 8, 5, 2, 0, 6, 5, 0, 6, 5, 9, 2, 9, 5, 4, 8, 4, 2, 5, 5, 6,
#        8, 3, 3, 5, 3, 7, 7, 6, 6, 9, 9, 8, 4, 4, 8, 2, 9, 8, 9, 7, 3, 2,
#        4, 5, 1, 4, 8, 7, 0, 3, 9, 6, 2, 6, 3, 2, 2, 8, 4, 7, 8, 2, 2, 8,
#        6, 7, 8, 3, 3, 8, 0, 4, 4, 1, 4, 4, 2, 5, 4, 1, 9, 3, 1, 9, 6, 5,
#        2, 3, 1, 7, 5, 5, 4, 3, 3, 6, 3, 7, 7, 9, 6, 6, 4, 4, 2, 9, 8, 5,
#        5, 8, 0, 9, 9, 6, 1, 6, 1, 6, 9, 0, 8, 9, 6, 0, 9, 0, 4, 9, 4, 7,
#        4, 1, 7, 0, 0, 4, 1, 6, 7, 1, 2, 2, 9, 0, 9, 3, 0, 8, 6, 7, 4, 3,
#        0, 5, 2, 1, 5, 7, 2, 0, 0, 0, 4, 9, 6, 0, 7, 0, 1, 6, 5, 7, 2, 5,
#        0, 1, 7, 3, 7, 1, 4, 5, 7, 2, 9, 2, 5, 0, 0, 1, 5, 5, 4, 3, 1, 8,
#        3, 3, 5, 8, 4, 6, 0, 8, 5, 7, 1, 0, 8, 1, 4, 7, 8, 1, 3, 9, 6, 2,
#        3, 2, 5, 6, 3, 3, 9, 0, 1, 7, 2, 7, 7, 0, 8, 1, 4, 3, 6, 5, 0, 3,
#        2, 2, 1, 9, 9, 8, 3, 2, 1, 4, 3, 4, 7, 6])

# %%
x.shape
# Out:
# (300, 2)

# %%
x.std()
# Out:
# 5.509921089839484

# %%
plt.xlabel('Feature 1')
plt.ylabel('feature 2')
plt.scatter(x[:,0],x[:,1])

# %%
x,y= make_blobs(n_samples=300, centers=4, cluster_std=0.60, random_state=0)

# %%
plt.xlabel('Feature 1')
plt.ylabel('feature 2')
plt.scatter(x[:,0],x[:,1])

# %% [markdown]
# #### create a object

# %%
dbscan=DBSCAN(eps=0.6,min_samples=5)
clusters= dbscan.fit_predict(x)

# %%
clusters
# Out:
# array([ 2,  0,  1,  0,  2, -1,  3,  1,  0,  0,  3,  0,  1,  0,  2,  1,  1,
#         2,  3,  3,  2,  2,  1,  3,  3,  1,  2,  1,  3,  1,  0,  0,  1,  0,
#         0,  0,  0,  0,  3,  2,  1,  3,  1,  1,  3,  3,  0,  3,  0,  2,  3,
#         2,  0,  2,  2,  3,  0,  3,  0,  2,  0,  1,  0,  3,  3,  3,  0,  2,
#         0,  3,  1,  3,  0,  3,  3,  0,  3,  1,  2,  0,  2,  1,  2,  2,  0,
#         1,  2,  1,  0,  0,  1,  2,  0,  3,  3,  1,  2,  2,  1,  3,  0,  2,
#         0,  2,  1,  2,  2,  1,  0,  1,  3,  3,  2,  0,  2,  1,  0,  2,  2,
#         1,  3,  2,  3,  2,  2,  2,  2,  3,  2,  3,  0,  3,  3,  2,  0,  3,
#         3,  0,  1,  0,  0,  3,  1,  3,  1,  3,  0,  1,  0,  0,  0,  1,  0,
#         1,  2,  3,  0,  3,  2,  1,  0,  1,  1,  2,  1,  3, -1,  1,  2,  1,
#         1,  0,  2,  1, -1,  0,  2,  2,  1,  3,  2,  1,  3,  3,  1,  1,  1,
#         1,  2,  0,  1,  3,  1,  1,  3,  3,  3,  1,  3,  0,  1,  3,  2,  3,
#         1, -1,  3,  0,  1,  0,  1,  3,  1,  1,  0,  3,  3,  2,  2,  1,  0,
#         2,  2,  3,  2,  3,  1,  0,  0,  1,  1,  0,  1,  2,  3,  1,  2,  3,
#         0,  3,  2,  1,  2,  0,  0,  0,  0,  3,  3,  0,  1,  3,  2,  1,  3,
#         3,  3,  2,  2,  0,  1,  1,  3,  2,  0,  3,  1,  0,  1,  2,  2,  3,
#         3, -1,  2,  2,  2,  1,  0,  0,  2,  2,  1,  2,  2,  2,  0,  3,  0,
#         1, -1,  2,  0,  0,  0,  2,  2,  1,  0,  3], dtype=int64)

# %% [markdown]
#  ### visualize the cluster

# %%
plt.xlabel('Feature 1')
plt.ylabel('feature 2')
plt.scatter(x[:,0],x[:,1],c=clusters)
