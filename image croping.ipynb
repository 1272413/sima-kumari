# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img=plt.imread('images/draw.png')

# %%
img.shape
# Out:
# (543, 655, 3)

# %%
plt.imshow(img)

# %%
new_img=img[150:300,200:350]

# %%
plt.imshow(new_img)

# %%
img2=img[15:75,75:90]

# %%
plt.imshow(img2)8

# %%
height,width,channel=img.shape

# %%
startRow=int(height*.15)
startcol=int(width*.15)
endRow=int(height*.85)
endcol=int(width*.85)

# %%
croppedImage=img[startRow:endRow,startcol:endcol]

# %%
plt.imshow(croppedImage)

# %%
x=np.array([[5,6,7],[1,2,3],[8,0,9]])
y=np.array([[3,5,6],[7,8,9],[4,6,8]])

# %%
x
# Out:
# array([[5, 6, 7],
#        [1, 2, 3],
#        [8, 0, 9]])

# %%
y
# Out:
# array([[3, 5, 6],
#        [7, 8, 9],
#        [4, 6, 8]])

# %%
z=np.hstack([x,y])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 z=np.hstack([x,y])
#
# File C:\ProgramData\anaconda3\Lib\site-packages\numpy\core\shape_base.py:359, in hstack(tup, dtype, casting)
#     357     return _nx.concatenate(arrs, 0, dtype=dtype, casting=casting)
#     358 else:
# --> 359     return _nx.concatenate(arrs, 1, dtype=dtype, casting=casting)
#
# ValueError: all the input array dimensions except for the concatenation axis must match exactly, but along dimension 0, the array at index 0 has size 9 and the array at index 1 has size 3

# %%
z
# Out:
# array([[5, 6, 7],
#        [1, 2, 3],
#        [8, 0, 9],
#        [3, 5, 6],
#        [7, 8, 9],
#        [4, 6, 8]])

# %%
x=np.vstack([x,y])

# %%
x
# Out:
# array([[5, 6, 7],
#        [1, 2, 3],
#        [8, 0, 9],
#        [3, 5, 6],
#        [7, 8, 9],
#        [4, 6, 8]])

# %%
#flip
flipped_horizontal=cv2.flip(img,0)

# %%
new_img=np.hstack([img,flipped_horizontal])

# %%
plt.imshow(new_img)

# %%
shear_x=-0.25
shear_y=0.45
image=cv2.imread('images/draw.png')
M=np.array([[1,shear_x,0],[shear_y,1,0],[0,0,1]])
rows,cols,_=image.shape
T=np.float32([[1,0,0],[0,1,50]])
img_tranlation=cv2.warpAffine(image,T,(int(cols*1.5),int(rows*1.5)))
sheared_img=cv2.warpPerspective(img_tranlation,M,(int(cols*1.5),int(rows*1.5),int(rows*1.5)))
cv2.imshow('img',sheared_img)
cv2.waitKey(0)
cv2.destroyWindow()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[51], line 8
#       6 T=np.float32([[1,0,0],[0,1,50]])
#       7 img_tranlation=cv2.warpAffine(image,T,(int(cols*1.5),int(rows*1.5)))
# ----> 8 sheared_img=cv2.warpPerspective(img_tranlation,M,(int(cols*1.5),int(rows*1.5),int(rows*1.5)))
#       9 cv2.imshow('img',sheared_img)
#      10 cv2.waitKey(0)
#
# error: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'warpPerspective'
# > Overload resolution failed:
# >  - Can't parse 'dsize'. Expected sequence length 2, got 3
# >  - Can't parse 'dsize'. Expected sequence length 2, got 3
